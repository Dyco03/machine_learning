# %%
import pandas as pd
import numpy as np
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt
df = pd.read_csv('mercedes_benz_listings_cleaned.csv')
features = ['Mileage_Miles']

#prepare data
data = df.dropna()



idx_train = data.sample(frac = 0.8).index

X_train = data.loc[idx_train,features].values
Y_train = data.loc[idx_train,'Price_USD'].values

X_test = data.drop(idx_train).loc[:,features].values
Y_test = data.drop(idx_train)['Price_USD'].values

# %%
n_features = 1
x,y = make_regression(n_samples=100,noise=10,n_features=n_features)

# %%
y = y.reshape((x.shape[0],1))

X = np.hstack([x,np.ones((y.shape[0],1))])

print(X.shape)
print(y.shape)
# Out:
# (100, 2)
# (100, 1)

# %% [markdown]
# # LINEAR REGRESSION CLASS

# %%
class LR :
    def __init__(self,n_features,ridge_lamda = 0):
        self.w = np.random.randn(n_features + 1,1)
        self.costs = []
        self.lamda = ridge_alpha

    def model(self,X):
        return X@self.w

    def cost(self, X,y):
        m = len(y)
        ridge = self.lamda * np.sum(self.w **2)
        return (1/2*m) * (np.sum((X@self.w - y) **2) + ridge)

    def grad(self,X,y):
        m = len(y)
        ridge = self.lamda * self.w
        return (1/m) * ( X.T.dot(X@self.w - y) + ridge)

    def descente_gradient(self,X,y,alpha,n_iterations):
        for i in range(0,n_iterations):
            self.w = self.w -alpha * self.grad(X,y)
            self.costs.append(self.cost(X,y))

    def fit_analytique(self,X,y):
        self.w = 0
        self.w = np.linalg.inv(X.T@X).dot(X.T@y)

# %%
lr = LR(n_features)
lr.descente_gradient(X,y,alpha=0.1,n_iterations=1000)

lr2 = LR(n_features)
lr2.fit_analytique(X,y)

predictions = lr.model(X)
predictions2  = lr2.model(X)

# %%
plt.scatter(x,y)
plt.plot(x,predictions2)

# %%
from sklearn.metrics import r2_score
score = r2_score(y,predictions2)
df = pd.DataFrame({
    'prediction' : predictions.ravel(),
    'prediction2' : predictions2.ravel()
    })
print(np.allclose(predictions,predictions2))
# Out:
# True
